# %%
import numpy as np
import scipy.sparse as sp
from sklearn.preprocessing import normalize

# %%
ff = "w4a_1_1"

# %%
error_Ahallow = np.load('./results_data/'+ff+'.npz')['error_Ahallow']
linfty_result = np.load('./results_data/'+ff+'.npz')['linfty_result']
l2_result = np.load('./results_data/'+ff+'.npz')['l2_result']
l2_result = np.load('./results_data/'+ff+'.npz')['l2_result']

# %%
ff = "w4a.txt"

# %%
#passRandomDraw.py
import numpy as np
import scipy.sparse as sp
import scipy.linalg as sp_linalg
from mpi4py import MPI
import time
from sklearn.preprocessing import normalize

# Just a useful function.
def diff(a, b):
        b = set(b)
        return [aa for aa in a if aa not in b]
    
def partition(lst, n):
    q, r = divmod(len(lst), n)
    indices = [q*i + min(i, r) for i in range(n+1)]
    return [lst[indices[i]:indices[i+1]] for i in range(n)]
    
def solve_linear(L,b):
    y = sp_linalg.solve_triangular(L,b,lower=True)
    return sp_linalg.solve_triangular(L,y,trans='T',lower=True)

def solve_quadratic(rhs):
    n = rhs.shape[0]
    Omega = np.zeros((n,n))
    
    if n > 1:
        for i in range(n):
            for j in range(i,n):
                if i == j:
                    if i != 0:
                        Omega[j,i] = np.sqrt(rhs[j,i] - np.sum(np.square(Omega[j,0:i])))
                    else:
                        Omega[j,i] = np.sqrt(rhs[j,i])
                else:
                    if i != 0:
                        temp = 0
                        for l in range(i):
                            temp = temp + Omega[j,l]*Omega[i,l]
                        Omega[j,i] = (rhs[j,i] - temp)/Omega[i,i]
                    else:
                        Omega[j,i] = rhs[j,i]/Omega[i,i]
    else:
        Omega[0,0] = np.sqrt(rhs[0,0])
        
    return Omega


LARS_Ahallow = []
block = 1

# %%
# Initialize MPI properties
comm = MPI.COMM_WORLD
size = comm.Get_size()
p = comm.Get_rank()

# Data generation and distribution
m = np.zeros([1],dtype=int)
n = np.zeros([1],dtype=int)

if p == 0:
    m[0] = np.load('./m_data/'+'m_'+ff+'.npz')['m']
    n[0] = np.load('./n_data/'+'n_'+ff+'.npz')['n']
    b = np.load('./b_data/'+'b_'+ff+'.npz')['b']
    A = sp.load_npz('./A_data/'+ff+'.npz').tolil()
        
    ide = sp.lil_matrix((n[0],m[0]),dtype=float)
        
    for i in range(m[0]):
        ide[i,i] = 5.0e-1
            
    A = A + ide

    #    A = A - np.tile(np.mean(A,axis=0),(n[0],1))
    A = normalize(A, axis=0, norm='l2').tolil()
        
    #    b = b - np.mean(b) 
    A_data = A.data.tolist()
    A_data_partitioned = partition(A_data, size)
    A_rows = A.rows.tolist()
    A_rows_partitioned = partition(A_rows, size)

    b = b.tolist()
    b_partitioned = partition(b, size)
    
comm.Bcast(m, root=0)
comm.Bcast(n, root=0)

n = n[0]
m = m[0]

iterations = int(np.ceil(min(m,n)/block))

if p!=0:
    A_data_partitioned = None
    A_rows_partitioned = None
    b_partitioned = None

A_data_local = comm.scatter(A_data_partitioned, root=0)
A_rows_local = comm.scatter(A_rows_partitioned, root=0)
b_local = np.asarray(comm.scatter(b_partitioned, root=0))

n_local = len(A_data_local)

A_local = sp.lil_matrix((n_local,m),dtype=float)
for row in range(n_local):
    ct = 0
    for col in A_rows_local[row]:
        A_local[row,col] = A_data_local[row][ct]
        ct = ct + 1
A_local = A_local.tocsr()

# Start measuring time
if p == 0:
    time_total = 0
    start = time.time()

b_sol_local = np.empty(n_local)
r_local = b_local

c_local = A_local.T.dot(r_local)
if p == 0:
    c = np.zeros(m)
else:
    c = np.empty(m)
comm.Allreduce(c_local, c, op=MPI.SUM)

A_hallow = []
B = np.argsort(-abs(c))[0:block]
c_const = abs(c[B[block-1]])
A_hallow.extend(B)
A_hallow_old = list(A_hallow)
l_A_hallow = len(A_hallow)
l_A_hallow_old = len(A_hallow_old)
A_hallow_c = diff(range(m), A_hallow)
    
error_Ahallow = []
linfty_result = [] 
l2_result = [] 
time_vector = []
    
if p == 0:
    end = time.time()
    time_total  = time_total + (end - start)
        
    linfty_result.extend([c_const])
    l2_result.extend([np.linalg.norm(c,2)])
        
    if len(LARS_Ahallow) != 0:
        if block == 1:
            temp = []
            temp.extend(LARS_Ahallow[0:block])
            if len(diff(temp,A_hallow)) != 0:
                error_Ahallow.extend([len(diff(temp,A_hallow))])
            else:
                error_Ahallow.extend([0])
        else:
            if len(diff(LARS_Ahallow[0:block],A_hallow)) != 0:
                error_Ahallow.extend([len(diff(LARS_Ahallow[0:block],A_hallow))])
            else:
                error_Ahallow.extend([0])
    start = time.time()

G_local = A_local[:,A_hallow].T.dot(A_local[:,A_hallow]).toarray()
if p == 0:
    G = np.zeros((l_A_hallow,l_A_hallow))
else:
    G = np.empty((l_A_hallow,l_A_hallow))
comm.Reduce(G_local, G, op=MPI.SUM, root=0)

w = np.zeros(l_A_hallow)
h = np.zeros(1)
compact_w_h = np.zeros(l_A_hallow+1)

if p == 0:
    L = np.linalg.cholesky(G)
    s = c[A_hallow] 
    q = solve_linear(L,s)
    h = np.asarray([1/np.sqrt(np.dot(s.T,q))])
    w = np.multiply(h,q)
    compact_w_h = np.concatenate((w, h), axis=0)    

comm.Bcast(compact_w_h, root=0)

w = compact_w_h[0:l_A_hallow]
h = np.asarray([compact_w_h[l_A_hallow]])

u_local = A_local[:,A_hallow].dot(w)

a = np.zeros(m)
a_local = A_local.T.dot(u_local)
comm.Allreduce(a_local, a, op=MPI.SUM)

gamma = np.zeros(1)

# %%
    for i in range(iterations - 1):

        l_A_hallow_c = len(A_hallow_c)

        if l_A_hallow_c < block:
            block = l_A_hallow_c

        compact_B_gamma = np.zeros(block+1)

        if p == 0:

            min_pos = np.zeros(l_A_hallow_c)
            for j in range(l_A_hallow_c):
                idx = A_hallow_c[j]
                val1 = (c_const - c[idx])/(h*c_const - a[idx])
                val2 = (c_const + c[idx])/(h*c_const + a[idx])
                min_pos[j] = min(val for val in [val1,val2] if val > 0)

            if l_A_hallow_c >= block:
                idx = np.argsort(min_pos)[0:block].tolist()
                B = np.asarray(A_hallow_c)[idx].tolist()
                gamma = 0.9*min_pos[idx[block-1]]
            else:
                idx = np.argsort(min_pos)[0:l_A_hallow_c].tolist()
                B = np.asarray(A_hallow_c)[idx].tolist()
                gamma = 0.9*min_pos[idx[l_A_hallow_c-1]]

            compact_B_gamma = np.concatenate((np.asarray(B),np.asarray([gamma])),axis=0) 

        comm.Bcast(compact_B_gamma, root=0)
        B = compact_B_gamma[0:block].astype(int)
        gamma = np.asarray([compact_B_gamma[block]])

        B = [B]

        b_sol_local = b_sol_local + np.multiply(gamma,u_local)

        c[A_hallow] = c[A_hallow]*(1-gamma*h)
        c[A_hallow_c] = c[A_hallow_c] - gamma*a[A_hallow_c]
        c_const = c_const*(1-gamma*h)
        
        temp = abs(A_local.T.dot(b_local - b_sol_local))
        print("error 2 ",  abs(max(abs(c[A_hallow_c]))-max(abs(c[A_hallow]))))
        print("max temp: ", max(temp))
        print("max abs(c): ", max(abs(c)))
        print("c_const: ", c_const)
        print("error: ", abs(c_const - max(abs(c))))
        if c_const + 1.0e-4 < max(abs(c)):
            print("FAILED 1")
            break;
        #if c_const < max(temp):
        #    print("FAILED 2")
        #    break;
            
        if block > 0:
            B = B[0]
        else:
            if p != 0:
                B = B[0]

        A_hallow.extend(B)
        l_A_hallow = len(A_hallow)
        A_hallow_c = diff(range(m), A_hallow)
        l_B = len(B)
        
        if p == 0:
            end = time.time()
            time_total  = time_total + (end - start)
            time_vector.extend([time_total])
            
            linfty_result.extend([c_const[0]])
            l2_result.extend([np.linalg.norm(c,2)])
        
            if len(LARS_Ahallow) != 0:
                if len(diff(LARS_Ahallow[0:len(B)*(i+2)],A_hallow)) != 0:
                    error_Ahallow.extend([len(diff(LARS_Ahallow[0:len(B)*(i+2)],A_hallow))])
                else:
                    error_Ahallow.extend([0])
            start = time.time()

        A_hallow_t_old_A_B_local = A_local[:,A_hallow_old].T.dot(A_local[:,B]).toarray() # fix all column slices
        if p == 0:
            A_hallow_t_old_A_B = np.zeros((l_A_hallow_old,l_B))
        else:
            A_hallow_t_old_A_B = np.empty((l_A_hallow_old,l_B))
        comm.Reduce(A_hallow_t_old_A_B_local, A_hallow_t_old_A_B, op=MPI.SUM, root=0)

        A_B_t_A_B_local = A_local[:,B].T.dot(A_local[:,B]).toarray()
        if p == 0:
            A_B_t_A_B = np.zeros((l_B,l_B))
        else:
            A_B_t_A_B = np.empty((l_B,l_B))
        comm.Reduce(A_B_t_A_B_local, A_B_t_A_B, op=MPI.SUM, root=0)    

        if p == 0:
            H = np.zeros((l_A_hallow_old,l_B))

            for j in range(l_B):
                H[:,j] = sp_linalg.solve_triangular(L,A_hallow_t_old_A_B[:,j],lower=True)

            rhs_Omega = A_B_t_A_B - np.dot(H.T,H)

            Omega = solve_quadratic(rhs_Omega)

            temp4 = np.concatenate((H.T, Omega), axis=1)

            #L = np.concatenate((L, np.zeros((l_A_hallow_old,l_B))), axis=1)
            #L = np.concatenate((L, temp4), axis=0)
            G_temp = A_local[:,A_hallow].T.dot(A_local[:,A_hallow]).toarray()
            print("rank: ", np.linalg.matrix_rank(G_temp))
            print("G_temp.shape: ", G_temp.shape)
            L = np.linalg.cholesky(A_local[:,A_hallow].T.dot(A_local[:,A_hallow]).toarray())

            s = c[A_hallow] 
            q = solve_linear(L,s)
            h = np.asarray([1/np.sqrt(np.dot(s.T,q))])
            w = np.multiply(h,q)
            compact_w_h = np.concatenate((w, h), axis=0)
        else:
            compact_w_h = np.zeros(l_A_hallow+1)

        comm.Bcast(compact_w_h, root=0)

        w = compact_w_h[0:l_A_hallow]
        h = np.asarray([compact_w_h[l_A_hallow]])

        u_local = A_local[:,A_hallow].dot(w)

        a_local = A_local.T.dot(u_local)

        comm.Allreduce(a_local, a, op=MPI.SUM)

        A_hallow_old = list(A_hallow)
        l_A_hallow = len(A_hallow)
        l_A_hallow_old = len(A_hallow_old)
# Out:
# error 2  0.218798906531
# max temp:  44.3273110684
# max abs(c):  44.3273110684
# c_const:  [ 44.32731107]
# error:  [ 0.]
# rank:  2
# G_temp.shape:  (2, 2)
# error 2  0.246773590996
# max temp:  38.3632972731
# max abs(c):  38.3632972731
# c_const:  [ 38.36329727]
# error:  [ 0.]
# rank:  3
# G_temp.shape:  (3, 3)
# error 2  0.139517536554
# max temp:  33.9201169811
# max abs(c):  33.9201169811
# c_const:  [ 33.92011698]
# error:  [ 0.]
# rank:  4
# G_temp.shape:  (4, 4)
# error 2  0.257397797763
# max temp:  27.3835107329
# max abs(c):  27.3835107329
# c_const:  [ 27.38351073]
# error:  [ 0.]
# rank:  5
# G_temp.shape:  (5, 5)
# error 2  0.091895638975
# max temp:  23.9219540695
# max abs(c):  23.9219540695
# c_const:  [ 23.92195407]
# error:  [ 0.]
# rank:  6
# G_temp.shape:  (6, 6)
# error 2  0.122562325066
# max temp:  20.4679898178
# max abs(c):  20.4679898178
# c_const:  [ 20.46798982]
# error:  [ 0.]
# rank:  7
# G_temp.shape:  (7, 7)
# error 2  0.0725898728812
# max temp:  19.8146809619
# max abs(c):  19.8146809619
# c_const:  [ 19.81468096]
# error:  [ 0.]
# rank:  8
# G_temp.shape:  (8, 8)
# error 2  0.0695155511993
# max temp:  16.511849724
# max abs(c):  16.511849724
# c_const:  [ 16.51184972]
# error:  [ 0.]
# rank:  9
# G_temp.shape:  (9, 9)
# error 2  0.045860707165
# max temp:  15.4902449719
# max abs(c):  15.4902449719
# c_const:  [ 15.49024497]
# error:  [ 0.]
# rank:  10
# G_temp.shape:  (10, 10)
# error 2  0.0174182380189
# max temp:  15.1066723685
# max abs(c):  15.1066723685
# c_const:  [ 15.10667237]
# error:  [ 0.]
# rank:  11
# G_temp.shape:  (11, 11)
# error 2  0.00376944637281
# max temp:  15.0126652924
# max abs(c):  15.0126652924
# c_const:  [ 15.01266529]
# error:  [ 0.]
# rank:  12
# G_temp.shape:  (12, 12)
# error 2  0.00441772992304
# max temp:  14.861207079
# max abs(c):  14.861207079
# c_const:  [ 14.86120708]
# error:  [ 0.]
# rank:  13
# G_temp.shape:  (13, 13)
# error 2  0.00334744610552
# max temp:  14.6265694203
# max abs(c):  14.6265694203
# c_const:  [ 14.62656942]
# error:  [ 0.]
# rank:  14
# G_temp.shape:  (14, 14)
# error 2  0.0187581342282
# max temp:  14.132254112
# max abs(c):  14.132254112
# c_const:  [ 14.13225411]
# error:  [ 0.]
# rank:  15
# G_temp.shape:  (15, 15)
# error 2  0.00833566111002
# max temp:  13.7836192875
# max abs(c):  13.7836192875
# c_const:  [ 13.78361929]
# error:  [ 0.]
# rank:  16
# G_temp.shape:  (16, 16)
# error 2  0.0125585387306
# max temp:  13.469917685
# max abs(c):  13.469917685
# c_const:  [ 13.46991769]
# error:  [ 0.]
# rank:  17
# G_temp.shape:  (17, 17)
# error 2  0.0531424746875
# max temp:  11.7392982665
# max abs(c):  11.7392982665
# c_const:  [ 11.73929827]
# error:  [ 0.]
# rank:  18
# G_temp.shape:  (18, 18)
# error 2  0.0185949473046
# max temp:  11.4016539739
# max abs(c):  11.4016539739
# c_const:  [ 11.40165397]
# error:  [ 0.]
# rank:  19
# G_temp.shape:  (19, 19)
# error 2  0.0297061529111
# max temp:  10.1630012394
# max abs(c):  10.1630012394
# c_const:  [ 10.16300124]
# error:  [ 0.]
# rank:  20
# G_temp.shape:  (20, 20)
# error 2  0.0169620289378
# max temp:  9.43420421853
# max abs(c):  9.43420421853
# c_const:  [ 9.43420422]
# error:  [ 0.]
# rank:  21
# G_temp.shape:  (21, 21)
# error 2  0.00642457052107
# max temp:  9.1324763251
# max abs(c):  9.1324763251
# c_const:  [ 9.13247633]
# error:  [ 0.]
# rank:  22
# G_temp.shape:  (22, 22)
# error 2  0.00587116130581
# max temp:  8.77759946086
# max abs(c):  8.77759946086
# c_const:  [ 8.77759946]
# error:  [ 0.]
# rank:  23
# G_temp.shape:  (23, 23)
# error 2  0.0296222641027
# max temp:  7.77938315261
# max abs(c):  7.77938315261
# c_const:  [ 7.77938315]
# error:  [ 0.]
# rank:  24
# G_temp.shape:  (24, 24)
# error 2  0.00296222641027
# max temp:  7.65720595573
# max abs(c):  7.65720595573
# c_const:  [ 7.65720596]
# error:  [ 0.]
# rank:  25
# G_temp.shape:  (25, 25)
# error 2  0.0181484957207
# max temp:  7.20975915914
# max abs(c):  7.20975915914
# c_const:  [ 7.20975916]
# error:  [ 0.]
# rank:  26
# G_temp.shape:  (26, 26)
# error 2  0.00943481557772
# max temp:  7.05065760209
# max abs(c):  7.05065760209
# c_const:  [ 7.0506576]
# error:  [ 0.]
# rank:  27
# G_temp.shape:  (27, 27)
# error 2  0.00742805584314
# max temp:  6.63600662653
# max abs(c):  6.63600662653
# c_const:  [ 6.63600663]
# error:  [ 0.]
# rank:  28
# G_temp.shape:  (28, 28)
# error 2  0.00808305293691
# max temp:  6.21187098212
# max abs(c):  6.21187098212
# c_const:  [ 6.21187098]
# error:  [ 0.]
# rank:  29
# G_temp.shape:  (29, 29)
# error 2  0.00375391102248
# max temp:  5.96288533809
# max abs(c):  5.96288533809
# c_const:  [ 5.96288534]
# error:  [ 0.]
# rank:  30
# G_temp.shape:  (30, 30)
# error 2  0.00750409688563
# max temp:  5.59939847639
# max abs(c):  5.59939847639
# c_const:  [ 5.59939848]
# error:  [ 0.]
# rank:  31
# G_temp.shape:  (31, 31)
# error 2  0.00398175102911
# max temp:  5.4220998075
# max abs(c):  5.4220998075
# c_const:  [ 5.42209981]
# error:  [ 0.]
# rank:  32
# G_temp.shape:  (32, 32)
# error 2  0.0107409135516
# max temp:  5.33778927414
# max abs(c):  5.33778927414
# c_const:  [ 5.33778927]
# error:  [ 0.]
# rank:  33
# G_temp.shape:  (33, 33)
# error 2  0.00157697189168
# max temp:  5.29573549052
# max abs(c):  5.29573549052
# c_const:  [ 5.29573549]
# error:  [ 0.]
# rank:  34
# G_temp.shape:  (34, 34)
# error 2  0.011985831673
# max temp:  5.08478901036
# max abs(c):  5.08478901036
# c_const:  [ 5.08478901]
# error:  [ 0.]
# rank:  35
# G_temp.shape:  (35, 35)
# error 2  0.0480654976655
# max temp:  4.63961771328
# max abs(c):  4.63961771328
# c_const:  [ 4.63961771]
# error:  [ 0.]
# rank:  36
# G_temp.shape:  (36, 36)
# error 2  0.00917899050566
# max temp:  4.55746624725
# max abs(c):  4.55746624725
# c_const:  [ 4.55746625]
# error:  [ 0.]
# rank:  37
# G_temp.shape:  (37, 37)
# error 2  0.00447943158898
# max temp:  4.46537218823
# max abs(c):  4.46537218823
# c_const:  [ 4.46537219]
# error:  [ 0.]
# rank:  38
# G_temp.shape:  (38, 38)
# error 2  0.000996455027131
# max temp:  4.42032059413
# max abs(c):  4.42032059413
# c_const:  [ 4.42032059]
# error:  [ 0.]
# rank:  39
# G_temp.shape:  (39, 39)
# error 2  0.00340083493106
# max temp:  4.33138329781
# max abs(c):  4.33138329781
# c_const:  [ 4.3313833]
# error:  [ 0.]
# rank:  40
# G_temp.shape:  (40, 40)
# error 2  0.0114251579343
# max temp:  4.23049257345
# max abs(c):  4.23049257345
# c_const:  [ 4.23049257]
# error:  [ 0.]
# rank:  41
# G_temp.shape:  (41, 41)
# error 2  0.0103432581418
# max temp:  4.01867082627
# max abs(c):  4.01867082627
# c_const:  [ 4.01867083]
# error:  [ 0.]
# rank:  42
# G_temp.shape:  (42, 42)
# error 2  0.00620363025925
# max temp:  3.8557627173
# max abs(c):  3.8557627173
# c_const:  [ 3.85576272]
# error:  [ 0.]
# rank:  43
# G_temp.shape:  (43, 43)
# error 2  0.00247453681174
# max temp:  3.80805564546
# max abs(c):  3.80805564546
# c_const:  [ 3.80805565]
# error:  [ 0.]
# rank:  44
# G_temp.shape:  (44, 44)
# error 2  0.00195302212497
# max temp:  3.79017707676
# max abs(c):  3.79017707676
# c_const:  [ 3.79017708]
# error:  [ 0.]
# rank:  45
# G_temp.shape:  (45, 45)
# error 2  0.000272192029734
# max temp:  3.73728463997
# max abs(c):  3.73728463997
# c_const:  [ 3.73728464]
# error:  [ 0.]
# rank:  46
# G_temp.shape:  (46, 46)
# error 2  0.00209837415106
# max temp:  3.50464739602
# max abs(c):  3.50464739602
# c_const:  [ 3.5046474]
# error:  [ 0.]
# rank:  47
# G_temp.shape:  (47, 47)
# error 2  0.00484442142768
# max temp:  3.44329184934
# max abs(c):  3.44329184934
# c_const:  [ 3.44329185]
# error:  [ 0.]
# rank:  48
# G_temp.shape:  (48, 48)
# error 2  0.0161940435058
# max temp:  3.27399964668
# max abs(c):  3.27399964668
# c_const:  [ 3.27399965]
# error:  [ 0.]
# rank:  49
# G_temp.shape:  (49, 49)
# error 2  0.00595414728038
# max temp:  3.1666429002
# max abs(c):  3.1666429002
# c_const:  [ 3.1666429]
# error:  [ 0.]
# rank:  50
# G_temp.shape:  (50, 50)
# error 2  0.000595414728037
# max temp:  3.11043612648
# max abs(c):  3.11043612648
# c_const:  [ 3.11043613]
# error:  [ 0.]
# rank:  51
# G_temp.shape:  (51, 51)
# error 2  0.00115476211959
# max temp:  3.1002844124
# max abs(c):  3.1002844124
# c_const:  [ 3.10028441]
# error:  [ 0.]
# rank:  52
# G_temp.shape:  (52, 52)
# error 2  0.000809250987789
# max temp:  3.0534392475
# max abs(c):  3.0534392475
# c_const:  [ 3.05343925]
# error:  [ 0.]
# rank:  53
# G_temp.shape:  (53, 53)
# error 2  0.00515157825343
# max temp:  2.9304846363
# max abs(c):  2.9304846363
# c_const:  [ 2.93048464]
# error:  [ 0.]
# rank:  54
# G_temp.shape:  (54, 54)
# error 2  0.00289359701447
# max temp:  2.89826671404
# max abs(c):  2.89826671404
# c_const:  [ 2.89826671]
# error:  [ 0.]
# rank:  55
# G_temp.shape:  (55, 55)
# error 2  0.000625980636278
# max temp:  2.88997273739
# max abs(c):  2.88997273739
# c_const:  [ 2.88997274]
# error:  [ 0.]
# rank:  56
# G_temp.shape:  (56, 56)
# error 2  0.000237998574885
# max temp:  2.88718329133
# max abs(c):  2.88718329133
# c_const:  [ 2.88718329]
# error:  [ 0.]
# rank:  57
# G_temp.shape:  (57, 57)
# error 2  0.00237969695191
# max temp:  2.83322652695
# max abs(c):  2.83322652695
# c_const:  [ 2.83322653]
# error:  [ 0.]
# rank:  58
# G_temp.shape:  (58, 58)
# error 2  0.00971669522833
# max temp:  2.69999036868
# max abs(c):  2.69999036868
# c_const:  [ 2.69999037]
# error:  [ 0.]
# rank:  59
# G_temp.shape:  (59, 59)
# error 2  0.000971669522833
# max temp:  2.6712727802
# max abs(c):  2.6712727802
# c_const:  [ 2.67127278]
# error:  [ 0.]
# rank:  60
# G_temp.shape:  (60, 60)
# error 2  0.000215902703586
# max temp:  2.66760221685
# max abs(c):  2.66760221685
# c_const:  [ 2.66760222]
# error:  [ 0.]
# rank:  61
# G_temp.shape:  (61, 61)
# error 2  0.0048783575661
# max temp:  2.58064091588
# max abs(c):  2.58064091588
# c_const:  [ 2.58064092]
# error:  [ 0.]
# rank:  62
# G_temp.shape:  (62, 62)
# error 2  0.0010279564536
# max temp:  2.56432531826
# max abs(c):  2.56432531826
# c_const:  [ 2.56432532]
# error:  [ 0.]
# rank:  63
# G_temp.shape:  (63, 63)
# error 2  0.000500133814941
# max temp:  2.55416003711
# max abs(c):  2.55416003711
# c_const:  [ 2.55416004]
# error:  [ 0.]
# rank:  64
# G_temp.shape:  (64, 64)
# error 2  0.00198609500158
# max temp:  2.52137550263
# max abs(c):  2.52137550263
# c_const:  [ 2.5213755]
# error:  [ 0.]
# rank:  65
# G_temp.shape:  (65, 65)
# error 2  0.00270258902114
# max temp:  2.49606536998
# max abs(c):  2.49606536998
# c_const:  [ 2.49606537]
# error:  [ 0.]
# rank:  66
# G_temp.shape:  (66, 66)
# error 2  0.00268374714204
# max temp:  2.47311531199
# max abs(c):  2.47311531199
# c_const:  [ 2.47311531]
# error:  [ 0.]
# rank:  67
# G_temp.shape:  (67, 67)
# error 2  0.00109987198646
# max temp:  2.43818950398
# max abs(c):  2.43818950398
# c_const:  [ 2.4381895]
# error:  [ 0.]
# rank:  68
# G_temp.shape:  (68, 68)
# error 2  0.000109987198646
# max temp:  2.42428885735
# max abs(c):  2.42428885735
# c_const:  [ 2.42428886]
# error:  [ 0.]
# rank:  69
# G_temp.shape:  (69, 69)
# error 2  0.000528169189007
# max temp:  2.40311189359
# max abs(c):  2.40311189359
# c_const:  [ 2.40311189]
# error:  [ 0.]
# rank:  70
# G_temp.shape:  (70, 70)
# error 2  0.000922858147824
# max temp:  2.38852679569
# max abs(c):  2.38852679569
# c_const:  [ 2.3885268]
# error:  [ 0.]
# rank:  71
# G_temp.shape:  (71, 71)
# error 2  0.00505347187977
# max temp:  2.35055035597
# max abs(c):  2.35055035597
# c_const:  [ 2.35055036]
# error:  [ 0.]
# rank:  72
# G_temp.shape:  (72, 72)
# error 2  0.00579820402364
# max temp:  2.29847758286
# max abs(c):  2.29847758286
# c_const:  [ 2.29847758]
# error:  [ 0.]
# rank:  73
# G_temp.shape:  (73, 73)
# error 2  0.00546738400604
# max temp:  2.24308932428
# max abs(c):  2.24308932428
# c_const:  [ 2.24308932]
# error:  [ 0.]
# rank:  74
# G_temp.shape:  (74, 74)
# error 2  0.00503392496838
# max temp:  2.19859678901
# max abs(c):  2.19859678901
# c_const:  [ 2.19859679]
# error:  [ 0.]
# rank:  75
# G_temp.shape:  (75, 75)
# error 2  0.00819741738491
# max temp:  2.13391558294
# max abs(c):  2.13391558294
# c_const:  [ 2.13391558]
# error:  [ 0.]
# rank:  76
# G_temp.shape:  (76, 76)
# error 2  0.00277705088368
# max temp:  2.10121622208
# max abs(c):  2.10121622208
# c_const:  [ 2.10121622]
# error:  [ 0.]
# rank:  77
# G_temp.shape:  (77, 77)
# error 2  0.000463701567513
# max temp:  2.08493420746
# max abs(c):  2.08493420746
# c_const:  [ 2.08493421]
# error:  [ 0.]
# rank:  78
# G_temp.shape:  (78, 78)
# error 2  0.000669583089699
# max temp:  2.05696333687
# max abs(c):  2.05696333687
# c_const:  [ 2.05696334]
# error:  [ 0.]
# rank:  79
# G_temp.shape:  (79, 79)
# error 2  0.00451866172506
# max temp:  2.01034038781
# max abs(c):  2.01034038781
# c_const:  [ 2.01034039]
# error:  [ 0.]
# rank:  80
# G_temp.shape:  (80, 80)
# error 2  0.00227705185584
# max temp:  1.97015483393
# max abs(c):  1.97015483393
# c_const:  [ 1.97015483]
# error:  [ 0.]
# rank:  81
# G_temp.shape:  (81, 81)
# error 2  0.000449057669982
# max temp:  1.96138526405
# max abs(c):  1.96138526405
# c_const:  [ 1.96138526]
# error:  [ 0.]
# rank:  82
# G_temp.shape:  (82, 82)
# error 2  0.00117564719348
# max temp:  1.94391089135
# max abs(c):  1.94391089135
# c_const:  [ 1.94391089]
# error:  [ 0.]
# rank:  83
# G_temp.shape:  (83, 83)
# error 2  0.00105712304301
# max temp:  1.92173830311
# max abs(c):  1.92173830311
# c_const:  [ 1.9217383]
# error:  [ 0.]
# rank:  84
# G_temp.shape:  (84, 84)
# error 2  0.00459566249921
# max temp:  1.88505749837
# max abs(c):  1.88505749837
# c_const:  [ 1.8850575]
# error:  [ 0.]
# rank:  85
# G_temp.shape:  (85, 85)
# error 2  0.00214342493403
# max temp:  1.78678419397
# max abs(c):  1.78678419397
# c_const:  [ 1.78678419]
# error:  [ 0.]
# rank:  86
# G_temp.shape:  (86, 86)
# error 2  0.000677364522421
# max temp:  1.76187050385
# max abs(c):  1.76187050385
# c_const:  [ 1.7618705]
# error:  [ 0.]
# rank:  87
# G_temp.shape:  (87, 87)
# error 2  0.00195306808557
# max temp:  1.75106267069
# max abs(c):  1.75106267069
# c_const:  [ 1.75106267]
# error:  [ 0.]
# rank:  88
# G_temp.shape:  (88, 88)
# error 2  0.00308456101385
# max temp:  1.72961342873
# max abs(c):  1.72961342873
# c_const:  [ 1.72961343]
# error:  [ 0.]
# rank:  89
# G_temp.shape:  (89, 89)
# error 2  0.00269671929437
# max temp:  1.69129779736
# max abs(c):  1.69129779736
# c_const:  [ 1.6912978]
# error:  [ 0.]
# rank:  90
# G_temp.shape:  (90, 90)
# error 2  0.000269671929437
# max temp:  1.68743547868
# max abs(c):  1.68743547868
# c_const:  [ 1.68743548]
# error:  [ 0.]
# rank:  91
# G_temp.shape:  (91, 91)
# error 2  0.000627363085124
# max temp:  1.67195007942
# max abs(c):  1.67195007942
# c_const:  [ 1.67195008]
# error:  [ 0.]
# rank:  92
# G_temp.shape:  (92, 92)
# error 2  0.00147354824146
# max temp:  1.64391928138
# max abs(c):  1.64391928138
# c_const:  [ 1.64391928]
# error:  [ 0.]
# rank:  93
# G_temp.shape:  (93, 93)
# error 2  0.00262776473419
# max temp:  1.62921745672
# max abs(c):  1.62921745672
# c_const:  [ 1.62921746]
# error:  [ 0.]
# rank:  94
# G_temp.shape:  (94, 94)
# error 2  0.00400714356166
# max temp:  1.58161117829
# max abs(c):  1.58161117829
# c_const:  [ 1.58161118]
# error:  [ 0.]
# rank:  95
# G_temp.shape:  (95, 95)
# error 2  0.000827703117124
# max temp:  1.55851645287
# max abs(c):  1.55851645287
# c_const:  [ 1.55851645]
# error:  [ 0.]
# rank:  96
# G_temp.shape:  (96, 96)
# error 2  0.00036832295142
# max temp:  1.55267567717
# max abs(c):  1.55267567717
# c_const:  [ 1.55267568]
# error:  [ 0.]
# rank:  97
# G_temp.shape:  (97, 97)
# error 2  0.00148879144679
# max temp:  1.53850738324
# max abs(c):  1.53850738324
# c_const:  [ 1.53850738]
# error:  [ 0.]
# rank:  98
# G_temp.shape:  (98, 98)
# error 2  0.00141199557478
# max temp:  1.51582270512
# max abs(c):  1.51582270512
# c_const:  [ 1.51582271]
# error:  [ 0.]
# rank:  99
# G_temp.shape:  (99, 99)
# error 2  0.000244135759309
# max temp:  1.50311088127
# max abs(c):  1.50311088127
# c_const:  [ 1.50311088]
# error:  [ 0.]
# rank:  100
# G_temp.shape:  (100, 100)
# error 2  0.00372843092071
# max temp:  1.45205454599
# max abs(c):  1.45205454599
# c_const:  [ 1.45205455]
# error:  [ 0.]
# rank:  101
# G_temp.shape:  (101, 101)
# error 2  0.00188729170066
# max temp:  1.43477596743
# max abs(c):  1.43477596743
# c_const:  [ 1.43477597]
# error:  [ 0.]
# rank:  102
# G_temp.shape:  (102, 102)
# error 2  0.00282857977313
# max temp:  1.41608721162
# max abs(c):  1.41608721162
# c_const:  [ 1.41608721]
# error:  [ 0.]
# rank:  103
# G_temp.shape:  (103, 103)
# error 2  0.00079695130319
# max temp:  1.38759872757
# max abs(c):  1.38759872757
# c_const:  [ 1.38759873]
# error:  [ 0.]
# rank:  104
# G_temp.shape:  (104, 104)
# error 2  0.00032032600687
# max temp:  1.35955340561
# max abs(c):  1.35955340561
# c_const:  [ 1.35955341]
# error:  [ 0.]
# rank:  105
# G_temp.shape:  (105, 105)
# error 2  0.00129506913429
# max temp:  1.33925787181
# max abs(c):  1.33925787181
# c_const:  [ 1.33925787]
# error:  [ 0.]
# rank:  106
# G_temp.shape:  (106, 106)
# error 2  0.00121514178983
# max temp:  1.3246224661
# max abs(c):  1.3246224661
# c_const:  [ 1.32462247]
# error:  [ 0.]
# rank:  107
# G_temp.shape:  (107, 107)
# error 2  0.00354658084721
# max temp:  1.29367367678
# max abs(c):  1.29367367678
# c_const:  [ 1.29367368]
# error:  [ 0.]
# rank:  108
# G_temp.shape:  (108, 108)
# error 2  0.00202260337225
# max temp:  1.27946130233
# max abs(c):  1.27946130233
# c_const:  [ 1.2794613]
# error:  [ 0.]
# rank:  109
# G_temp.shape:  (109, 109)
# error 2  0.000202260337225
# max temp:  1.27215165799
# max abs(c):  1.27215165799
# c_const:  [ 1.27215166]
# error:  [ 0.]
# rank:  110
# G_temp.shape:  (110, 110)
# error 2  0.00043643248085
# max temp:  1.26876768368
# max abs(c):  1.26876768368
# c_const:  [ 1.26876768]
# error:  [ 0.]
# rank:  111
# G_temp.shape:  (111, 111)
# error 2  0.000645033355653
# max temp:  1.26199406496
# max abs(c):  1.26199406496
# c_const:  [ 1.26199406]
# error:  [ 0.]
# rank:  112
# G_temp.shape:  (112, 112)
# error 2  0.00132427018992
# max temp:  1.25147652233
# max abs(c):  1.25147652233
# c_const:  [ 1.25147652]
# error:  [ 0.]
# rank:  113
# G_temp.shape:  (113, 113)
# error 2  0.00215718611609
# max temp:  1.23216816914
# max abs(c):  1.23216816914
# c_const:  [ 1.23216817]
# error:  [ 0.]
# rank:  114
# G_temp.shape:  (114, 114)
# error 2  0.00031390958316
# max temp:  1.22610299298
# max abs(c):  1.22610299298
# c_const:  [ 1.22610299]
# error:  [ 0.]
# rank:  115
# G_temp.shape:  (115, 115)
# error 2  0.00363418636554
# max temp:  1.1799861335
# max abs(c):  1.1799861335
# c_const:  [ 1.17998613]
# error:  [ 0.]
# rank:  116
# G_temp.shape:  (116, 116)
# error 2  0.000884569545342
# max temp:  1.16856003711
# max abs(c):  1.16856003711
# c_const:  [ 1.16856004]
# error:  [ 0.]
# rank:  117
# G_temp.shape:  (117, 117)
# error 2  0.0035118167464
# max temp:  1.14868565636
# max abs(c):  1.14868565636
# c_const:  [ 1.14868566]
# error:  [ 0.]
# rank:  118
# G_temp.shape:  (118, 118)
# error 2  0.00227730975487
# max temp:  1.12980024888
# max abs(c):  1.12980024888
# c_const:  [ 1.12980025]
# error:  [ 0.]
# rank:  119
# G_temp.shape:  (119, 119)
# error 2  0.00166079458352
# max temp:  1.11655288402
# max abs(c):  1.11655288402
# c_const:  [ 1.11655288]
# error:  [ 0.]
# rank:  120
# G_temp.shape:  (120, 120)
# error 2  0.000901294472743
# max temp:  1.1105689034
# max abs(c):  1.1105689034
# c_const:  [ 1.1105689]
# error:  [ 0.]
# rank:  121
# G_temp.shape:  (121, 121)
# error 2  0.00192499908801
# max temp:  1.08668372848
# max abs(c):  1.08668372848
# c_const:  [ 1.08668373]
# error:  [ 0.]
# rank:  122
# G_temp.shape:  (122, 122)
# error 2  0.00300941072143
# max temp:  1.0682648806
# max abs(c):  1.0682648806
# c_const:  [ 1.06826488]
# error:  [ 0.]
# rank:  123
# G_temp.shape:  (123, 123)
# error 2  0.00749823979116
# max temp:  1.02906421222
# max abs(c):  1.02906421222
# c_const:  [ 1.02906421]
# error:  [ 0.]
# rank:  124
# G_temp.shape:  (124, 124)
# error 2  0.00115549198095
# max temp:  1.0154845583
# max abs(c):  1.0154845583
# c_const:  [ 1.01548456]
# error:  [ 0.]
# rank:  125
# G_temp.shape:  (125, 125)
# error 2  0.000740665773485
# max temp:  1.00797135495
# max abs(c):  1.00797135495
# c_const:  [ 1.00797135]
# error:  [ 0.]
# rank:  126
# G_temp.shape:  (126, 126)
# error 2  0.000113860965807
# max temp:  1.00699753026
# max abs(c):  1.00699753026
# c_const:  [ 1.00699753]
# error:  [ 0.]
# rank:  127
# G_temp.shape:  (127, 127)
# error 2  0.00580920224095
# max temp:  0.967021813698
# max abs(c):  0.967021813698
# c_const:  [ 0.96702181]
# error:  [ 0.]
# rank:  128
# G_temp.shape:  (128, 128)
# error 2  0.000655840429655
# max temp:  0.920926252002
# max abs(c):  0.920926252002
# c_const:  [ 0.92092625]
# error:  [ 0.]
# rank:  129
# G_temp.shape:  (129, 129)
# error 2  6.55840429655e-05
# max temp:  0.914352094864
# max abs(c):  0.914352094864
# c_const:  [ 0.91435209]
# error:  [ 0.]
# rank:  130
# G_temp.shape:  (130, 130)
# error 2  0.000622041041491
# max temp:  0.905210360619
# max abs(c):  0.905210360619
# c_const:  [ 0.90521036]
# error:  [ 0.]
# rank:  131
# G_temp.shape:  (131, 131)
# error 2  0.00263059182316
# max temp:  0.860859061846
# max abs(c):  0.860859061846
# c_const:  [ 0.86085906]
# error:  [ 0.]
# rank:  132
# G_temp.shape:  (132, 132)
# error 2  0.000263059182316
# max temp:  0.849982608436
# max abs(c):  0.849982608436
# c_const:  [ 0.84998261]
# error:  [ 0.]
# rank:  133
# G_temp.shape:  (133, 133)
# error 2  0.000283253139016
# max temp:  0.843841037732
# max abs(c):  0.843841037732
# c_const:  [ 0.84384104]
# error:  [ 0.]
# rank:  134
# G_temp.shape:  (134, 134)
# error 2  0.000494501263595
# max temp:  0.838720346003
# max abs(c):  0.838720346003
# c_const:  [ 0.83872035]
# error:  [ 0.]
# rank:  135
# G_temp.shape:  (135, 135)
# error 2  0.00284690825823
# max temp:  0.820527490593
# max abs(c):  0.820527490593
# c_const:  [ 0.82052749]
# error:  [ 0.]
# rank:  136
# G_temp.shape:  (136, 136)
# error 2  0.00176448354769
# max temp:  0.792268969798
# max abs(c):  0.792268969798
# c_const:  [ 0.79226897]
# error:  [ 0.]
# rank:  137
# G_temp.shape:  (137, 137)
# error 2  0.00315895223179
# max temp:  0.725707410595
# max abs(c):  0.725707410595
# c_const:  [ 0.72570741]
# error:  [ 0.]
# rank:  138
# G_temp.shape:  (138, 138)
# error 2  0.00174699308408
# max temp:  0.706665560271
# max abs(c):  0.706665560271
# c_const:  [ 0.70666556]
# error:  [ 0.]
# rank:  139
# G_temp.shape:  (139, 139)
# error 2  0.000331983385254
# max temp:  0.700703456586
# max abs(c):  0.700703456586
# c_const:  [ 0.70070346]
# error:  [ 0.]
# rank:  140
# G_temp.shape:  (140, 140)
# error 2  0.00070413673823
# max temp:  0.69469931617
# max abs(c):  0.69469931617
# c_const:  [ 0.69469932]
# error:  [ 0.]
# rank:  141
# G_temp.shape:  (141, 141)
# error 2  0.00014371638743
# max temp:  0.693047035968
# max abs(c):  0.693047035968
# c_const:  [ 0.69304704]
# error:  [ 0.]
# rank:  142
# G_temp.shape:  (142, 142)
# error 2  0.000631323628585
# max temp:  0.68331685042
# max abs(c):  0.68331685042
# c_const:  [ 0.68331685]
# error:  [ 0.]
# rank:  143
# G_temp.shape:  (143, 143)
# error 2  0.000809992346789
# max temp:  0.674616176432
# max abs(c):  0.674616176432
# c_const:  [ 0.67461618]
# error:  [ 0.]
# rank:  144
# G_temp.shape:  (144, 144)
# error 2  0.000399969933582
# max temp:  0.671150075719
# max abs(c):  0.67115007572
# c_const:  [ 0.67115008]
# error:  [ 0.]
# rank:  145
# G_temp.shape:  (145, 145)
# error 2  0.000395817592651
# max temp:  0.663205777158
# max abs(c):  0.663205777158
# c_const:  [ 0.66320578]
# error:  [ 0.]
# rank:  146
# G_temp.shape:  (146, 146)
# error 2  0.00100649845847
# max temp:  0.653448001846
# max abs(c):  0.653448001846
# c_const:  [ 0.653448]
# error:  [ 0.]
# rank:  147
# G_temp.shape:  (147, 147)
# error 2  0.00101227176114
# max temp:  0.645519155255
# max abs(c):  0.645519155255
# c_const:  [ 0.64551916]
# error:  [ 0.]
# rank:  148
# G_temp.shape:  (148, 148)
# error 2  0.00053991147002
# max temp:  0.641449779349
# max abs(c):  0.641449779349
# c_const:  [ 0.64144978]
# error:  [ 0.]
# rank:  149
# G_temp.shape:  (149, 149)
# error 2  0.00289117905811
# max temp:  0.608140568528
# max abs(c):  0.608140568528
# c_const:  [ 0.60814057]
# error:  [ 0.]
# rank:  150
# G_temp.shape:  (150, 150)
# error 2  0.00117102110779
# max temp:  0.593717724224
# max abs(c):  0.593717724224
# c_const:  [ 0.59371772]
# error:  [ 0.]
# rank:  151
# G_temp.shape:  (151, 151)
# error 2  0.00114597963172
# max temp:  0.576394540055
# max abs(c):  0.576394540055
# c_const:  [ 0.57639454]
# error:  [ 0.]
# rank:  152
# G_temp.shape:  (152, 152)
# error 2  0.00061424955317
# max temp:  0.571526108078
# max abs(c):  0.571526108078
# c_const:  [ 0.57152611]
# error:  [ 0.]
# rank:  153
# G_temp.shape:  (153, 153)
# error 2  0.00127599614271
# max temp:  0.557562163577
# max abs(c):  0.557562163577
# c_const:  [ 0.55756216]
# error:  [ 0.]
# rank:  154
# G_temp.shape:  (154, 154)
# error 2  0.000385149054045
# max temp:  0.554721075467
# max abs(c):  0.554721075468
# c_const:  [ 0.55472108]
# error:  [ 0.]
# rank:  155
# G_temp.shape:  (155, 155)
# error 2  0.000235844493649
# max temp:  0.550286444093
# max abs(c):  0.550286444093
# c_const:  [ 0.55028644]
# error:  [ 0.]
# rank:  156
# G_temp.shape:  (156, 156)
# error 2  0.000389159695014
# max temp:  0.546872076292
# max abs(c):  0.546872076292
# c_const:  [ 0.54687208]
# error:  [ 0.]
# rank:  157
# G_temp.shape:  (157, 157)
# error 2  0.000266886162906
# max temp:  0.545118685416
# max abs(c):  0.545118685416
# c_const:  [ 0.54511869]
# error:  [ 0.]
# rank:  158
# G_temp.shape:  (158, 158)
# error 2  0.00256637278165
# max temp:  0.526883390408
# max abs(c):  0.526883390408
# c_const:  [ 0.52688339]
# error:  [ 0.]
# rank:  159
# G_temp.shape:  (159, 159)
# error 2  0.0021979865557
# max temp:  0.498200011939
# max abs(c):  0.498200011939
# c_const:  [ 0.49820001]
# error:  [ 0.]
# rank:  160
# G_temp.shape:  (160, 160)
# error 2  0.000234709888865
# max temp:  0.494101526667
# max abs(c):  0.494101526667
# c_const:  [ 0.49410153]
# error:  [ 0.]
# rank:  161
# G_temp.shape:  (161, 161)
# error 2  4.42236696124e-05
# max temp:  0.493602184019
# max abs(c):  0.493602184019
# c_const:  [ 0.49360218]
# error:  [ 0.]
# rank:  162
# G_temp.shape:  (162, 162)
# error 2  0.00105221620999
# max temp:  0.485810062111
# max abs(c):  0.485810062111
# c_const:  [ 0.48581006]
# error:  [ 0.]
# rank:  163
# G_temp.shape:  (163, 163)
# error 2  0.000591187345526
# max temp:  0.48150784508
# max abs(c):  0.48150784508
# c_const:  [ 0.48150785]
# error:  [ 0.]
# rank:  164
# G_temp.shape:  (164, 164)
# error 2  0.000706963996041
# max temp:  0.473527887297
# max abs(c):  0.473527887297
# c_const:  [ 0.47352789]
# error:  [ 0.]
# rank:  165
# G_temp.shape:  (165, 165)
# error 2  0.000123978101035
# max temp:  0.471073723723
# max abs(c):  0.471073723723
# c_const:  [ 0.47107372]
# error:  [ 0.]
# rank:  166
# G_temp.shape:  (166, 166)
# error 2  0.000162690383411
# max temp:  0.469292924016
# max abs(c):  0.469292924016
# c_const:  [ 0.46929292]
# error:  [ 0.]
# rank:  167
# G_temp.shape:  (167, 167)
# error 2  0.000793064867528
# max temp:  0.461442325303
# max abs(c):  0.461442325303
# c_const:  [ 0.46144233]
# error:  [ 0.]
# rank:  168
# G_temp.shape:  (168, 168)
# error 2  0.000160182193877
# max temp:  0.455774302002
# max abs(c):  0.455774302002
# c_const:  [ 0.4557743]
# error:  [ 0.]
# rank:  169
# G_temp.shape:  (169, 169)
# error 2  4.15130684867e-05
# max temp:  0.453304218393
# max abs(c):  0.453304218393
# c_const:  [ 0.45330422]
# error:  [ 0.]
# rank:  170
# G_temp.shape:  (170, 170)
# error 2  4.15130684867e-06
# max temp:  0.452918602154
# max abs(c):  0.452918602154
# c_const:  [ 0.4529186]
# error:  [ 0.]
# rank:  171
# G_temp.shape:  (171, 171)
# error 2  0.000399371697708
# max temp:  0.447096540448
# max abs(c):  0.447096540448
# c_const:  [ 0.44709654]
# error:  [ 0.]
# rank:  172
# G_temp.shape:  (172, 172)
# error 2  0.000446076719053
# max temp:  0.443601921342
# max abs(c):  0.443601921343
# c_const:  [ 0.44360192]
# error:  [ 0.]
# rank:  173
# G_temp.shape:  (173, 173)
# error 2  0.00115570368246
# max temp:  0.43383226967
# max abs(c):  0.43383226967
# c_const:  [ 0.43383227]
# error:  [ 0.]
# rank:  174
# G_temp.shape:  (174, 174)
# error 2  0.000866187629262
# max temp:  0.429529391027
# max abs(c):  0.429529391027
# c_const:  [ 0.42952939]
# error:  [ 0.]
# rank:  175
# G_temp.shape:  (175, 175)
# error 2  0.00301169725051
# max temp:  0.413659326367
# max abs(c):  0.413659326367
# c_const:  [ 0.41365933]
# error:  [ 0.]
# rank:  176
# G_temp.shape:  (176, 176)
# error 2  0.00133312472446
# max temp:  0.40469126022
# max abs(c):  0.40469126022
# c_const:  [ 0.40469126]
# error:  [ 0.]
# rank:  177
# G_temp.shape:  (177, 177)
# error 2  0.000364253757882
# max temp:  0.400680435779
# max abs(c):  0.400680435779
# c_const:  [ 0.40068044]
# error:  [ 0.]
# rank:  178
# G_temp.shape:  (178, 178)
# error 2  0.000209860180852
# max temp:  0.398868213243
# max abs(c):  0.398868213243
# c_const:  [ 0.39886821]
# error:  [ 0.]
# rank:  179
# G_temp.shape:  (179, 179)
# error 2  0.000271971497097
# max temp:  0.396756512106
# max abs(c):  0.396756512106
# c_const:  [ 0.39675651]
# error:  [ 0.]
# rank:  180
# G_temp.shape:  (180, 180)
# error 2  0.00246281177208
# max temp:  0.37729124085
# max abs(c):  0.37729124085
# c_const:  [ 0.37729124]
# error:  [ 0.]
# rank:  181
# G_temp.shape:  (181, 181)
# error 2  0.00078944566022
# max temp:  0.37144529397
# max abs(c):  0.37144529397
# c_const:  [ 0.37144529]
# error:  [ 0.]
# rank:  182
# G_temp.shape:  (182, 182)
# error 2  0.0018958232119
# max temp:  0.360797985803
# max abs(c):  0.360797985803
# c_const:  [ 0.36079799]
# error:  [ 0.]
# rank:  183
# G_temp.shape:  (183, 183)
# error 2  0.00289335129732
# max temp:  0.33858184941
# max abs(c):  0.33858184941
# c_const:  [ 0.33858185]
# error:  [ 0.]
# rank:  184
# G_temp.shape:  (184, 184)
# error 2  0.000780766537199
# max temp:  0.334076285212
# max abs(c):  0.334076285212
# c_const:  [ 0.33407629]
# error:  [ 0.]
# rank:  185
# G_temp.shape:  (185, 185)
# error 2  0.000738479413683
# max temp:  0.326671436362
# max abs(c):  0.326671436362
# c_const:  [ 0.32667144]
# error:  [ 0.]
# rank:  186
# G_temp.shape:  (186, 186)
# error 2  0.000142455688702
# max temp:  0.324939253435
# max abs(c):  0.324939253435
# c_const:  [ 0.32493925]
# error:  [ 0.]
# rank:  187
# G_temp.shape:  (187, 187)
# error 2  4.29447740757e-05
# max temp:  0.324742400724
# max abs(c):  0.324742400724
# c_const:  [ 0.3247424]
# error:  [ 0.]
# rank:  188
# G_temp.shape:  (188, 188)
# error 2  7.33934407244e-05
# max temp:  0.323248503267
# max abs(c):  0.323248503267
# c_const:  [ 0.3232485]
# error:  [ 0.]
# rank:  189
# G_temp.shape:  (189, 189)
# error 2  0.000146004517288
# max temp:  0.319238973023
# max abs(c):  0.319238973023
# c_const:  [ 0.31923897]
# error:  [ 0.]
# rank:  190
# G_temp.shape:  (190, 190)
# error 2  0.000947490414698
# max temp:  0.313040074255
# max abs(c):  0.313040074255
# c_const:  [ 0.31304007]
# error:  [ 0.]
# rank:  191
# G_temp.shape:  (191, 191)
# error 2  0.00306134784494
# max temp:  0.298235220577
# max abs(c):  0.298235220577
# c_const:  [ 0.29823522]
# error:  [ 0.]
# rank:  192
# G_temp.shape:  (192, 192)
# error 2  0.000928880740843
# max temp:  0.293398619268
# max abs(c):  0.293398619268
# c_const:  [ 0.29339862]
# error:  [ 0.]
# rank:  193
# G_temp.shape:  (193, 193)
# error 2  0.000351085707035
# max temp:  0.291414205734
# max abs(c):  0.291414205734
# c_const:  [ 0.29141421]
# error:  [ 0.]
# rank:  194
# G_temp.shape:  (194, 194)
# error 2  0.00079344203175
# max temp:  0.286581005471
# max abs(c):  0.286581005471
# c_const:  [ 0.28658101]
# error:  [ 0.]
# rank:  195
# G_temp.shape:  (195, 195)
# error 2  0.000995623289425
# max temp:  0.277532616169
# max abs(c):  0.277532616169
# c_const:  [ 0.27753262]
# error:  [ 0.]
# rank:  196
# G_temp.shape:  (196, 196)
# error 2  0.000291922387124
# max temp:  0.273743269136
# max abs(c):  0.273743269136
# c_const:  [ 0.27374327]
# error:  [ 0.]
# rank:  197
# G_temp.shape:  (197, 197)
# error 2  0.000369743036859
# max temp:  0.272019196403
# max abs(c):  0.272019196403
# c_const:  [ 0.2720192]
# error:  [ 0.]
# rank:  198
# G_temp.shape:  (198, 198)
# error 2  0.00128036997166
# max temp:  0.265440804319
# max abs(c):  0.265440804319
# c_const:  [ 0.2654408]
# error:  [ 0.]
# rank:  199
# G_temp.shape:  (199, 199)
# error 2  0.000272576538081
# max temp:  0.263332227105
# max abs(c):  0.263332227105
# c_const:  [ 0.26333223]
# error:  [ 0.]
# rank:  200
# G_temp.shape:  (200, 200)
# error 2  0.000238371622387
# max temp:  0.261864199481
# max abs(c):  0.261864199481
# c_const:  [ 0.2618642]
# error:  [ 0.]
# rank:  201
# G_temp.shape:  (201, 201)
# error 2  0.000454907734973
# max temp:  0.259279691578
# max abs(c):  0.259279691578
# c_const:  [ 0.25927969]
# error:  [ 0.]
# rank:  202
# G_temp.shape:  (202, 202)
# error 2  0.000162929908483
# max temp:  0.25803714223
# max abs(c):  0.25803714223
# c_const:  [ 0.25803714]
# error:  [ 0.]
# rank:  203
# G_temp.shape:  (203, 203)
# error 2  0.000224474891685
# max temp:  0.254994316294
# max abs(c):  0.254994316294
# c_const:  [ 0.25499432]
# error:  [ 0.]
# rank:  204
# G_temp.shape:  (204, 204)
# error 2  2.94131776058e-05
# max temp:  0.254079474066
# max abs(c):  0.254079474066
# c_const:  [ 0.25407947]
# error:  [ 0.]
# rank:  205
# G_temp.shape:  (205, 205)
# error 2  0.000896657258442
# max temp:  0.249129439238
# max abs(c):  0.249129439238
# c_const:  [ 0.24912944]
# error:  [ 0.]
# rank:  206
# G_temp.shape:  (206, 206)
# error 2  0.000507480736483
# max temp:  0.246570765513
# max abs(c):  0.246570765513
# c_const:  [ 0.24657077]
# error:  [ 0.]
# rank:  207
# G_temp.shape:  (207, 207)
# error 2  0.00128487949645
# max temp:  0.236410560647
# max abs(c):  0.236410560647
# c_const:  [ 0.23641056]
# error:  [ 0.]
# rank:  208
# G_temp.shape:  (208, 208)
# error 2  0.000782585674881
# max temp:  0.230866922042
# max abs(c):  0.230866922042
# c_const:  [ 0.23086692]
# error:  [ 0.]
# rank:  209
# G_temp.shape:  (209, 209)
# error 2  0.000316890591838
# max temp:  0.225722335951
# max abs(c):  0.225722335951
# c_const:  [ 0.22572234]
# error:  [ 0.]
# rank:  210
# G_temp.shape:  (210, 210)
# error 2  0.000132907329125
# max temp:  0.224795860867
# max abs(c):  0.224795860867
# c_const:  [ 0.22479586]
# error:  [ 0.]
# rank:  211
# G_temp.shape:  (211, 211)
# error 2  1.98191604567e-05
# max temp:  0.224676968101
# max abs(c):  0.224676968101
# c_const:  [ 0.22467697]
# error:  [ 0.]
# rank:  212
# G_temp.shape:  (212, 212)
# error 2  1.16945069865e-05
# max temp:  0.224127046765
# max abs(c):  0.224127046765
# c_const:  [ 0.22412705]
# error:  [ 0.]
# rank:  213
# G_temp.shape:  (213, 213)
# error 2  0.000121696968039
# max temp:  0.223255907877
# max abs(c):  0.223255907877
# c_const:  [ 0.22325591]
# error:  [ 0.]
# rank:  214
# G_temp.shape:  (214, 214)
# error 2  0.000252484860623
# max temp:  0.222226410097
# max abs(c):  0.222226410097
# c_const:  [ 0.22222641]
# error:  [ 0.]
# rank:  215
# G_temp.shape:  (215, 215)
# error 2  0.000886887354587
# max temp:  0.217667056683
# max abs(c):  0.217667056683
# c_const:  [ 0.21766706]
# error:  [ 0.]
# rank:  216
# G_temp.shape:  (216, 216)
# error 2  0.00067985608483
# max temp:  0.213495488685
# max abs(c):  0.213495488685
# c_const:  [ 0.21349549]
# error:  [ 0.]
# rank:  217
# G_temp.shape:  (217, 217)
# error 2  0.000785291353746
# max temp:  0.192324943353
# max abs(c):  0.192324943353
# c_const:  [ 0.19232494]
# error:  [ 0.]
# rank:  218
# G_temp.shape:  (218, 218)
# error 2  0.000734151214484
# max temp:  0.188885529129
# max abs(c):  0.188885529129
# c_const:  [ 0.18888553]
# error:  [ 0.]
# rank:  219
# G_temp.shape:  (219, 219)
# error 2  0.000470163535139
# max temp:  0.177854061077
# max abs(c):  0.177854061077
# c_const:  [ 0.17785406]
# error:  [ 0.]
# rank:  220
# G_temp.shape:  (220, 220)
# error 2  0.00028510155036
# max temp:  0.170137312166
# max abs(c):  0.170137312166
# c_const:  [ 0.17013731]
# error:  [ 0.]
# rank:  221
# G_temp.shape:  (221, 221)
# error 2  0.00012411410226
# max temp:  0.16380271351
# max abs(c):  0.163802713511
# c_const:  [ 0.16380271]
# error:  [ 0.]
# rank:  222
# G_temp.shape:  (222, 222)
# error 2  1.88803981653e-05
# max temp:  0.159660546242
# max abs(c):  0.159660546242
# c_const:  [ 0.15966055]
# error:  [ 0.]
# rank:  223
# G_temp.shape:  (223, 223)
# error 2  1.88803981652e-06
# max temp:  0.158989063395
# max abs(c):  0.158989063396
# c_const:  [ 0.15898906]
# error:  [ 0.]
# rank:  224
# G_temp.shape:  (224, 224)
# error 2  0.00106539552813
# max temp:  0.153001137145
# max abs(c):  0.153001137145
# c_const:  [ 0.15300114]
# error:  [ 0.]
# rank:  225
# G_temp.shape:  (225, 225)
# error 2  0.000372521114989
# max temp:  0.149703505673
# max abs(c):  0.149703505673
# c_const:  [ 0.14970351]
# error:  [ 0.]
# rank:  226
# G_temp.shape:  (226, 226)
# error 2  0.000661864994726
# max temp:  0.145917989667
# max abs(c):  0.145917989667
# c_const:  [ 0.14591799]
# error:  [ 0.]
# rank:  227
# G_temp.shape:  (227, 227)
# error 2  0.000562366681396
# max temp:  0.143222980706
# max abs(c):  0.143222980706
# c_const:  [ 0.14322298]
# error:  [ 0.]
# rank:  228
# G_temp.shape:  (228, 228)
# error 2  0.000220721083084
# max temp:  0.139600938437
# max abs(c):  0.139600938437
# c_const:  [ 0.13960094]
# error:  [ 0.]
# rank:  229
# G_temp.shape:  (229, 229)
# error 2  0.000308562954703
# max temp:  0.13727131554
# max abs(c):  0.13727131554
# c_const:  [ 0.13727132]
# error:  [ 0.]
# rank:  230
# G_temp.shape:  (230, 230)
# error 2  0.00024971233422
# max temp:  0.133772264944
# max abs(c):  0.133772264944
# c_const:  [ 0.13377226]
# error:  [ 0.]
# rank:  231
# G_temp.shape:  (231, 231)
# error 2  0.00024062905919
# max temp:  0.13296837058
# max abs(c):  0.13296837058
# c_const:  [ 0.13296837]
# error:  [ 0.]
# rank:  232
# G_temp.shape:  (232, 232)
# error 2  0.000421619820053
# max temp:  0.13082466605
# max abs(c):  0.13082466605
# c_const:  [ 0.13082467]
# error:  [ 0.]
# rank:  233
# G_temp.shape:  (233, 233)
# error 2  0.000571662190251
# max temp:  0.126026984252
# max abs(c):  0.126026984252
# c_const:  [ 0.12602698]
# error:  [ 0.]
# rank:  234
# G_temp.shape:  (234, 234)
# error 2  0.000406284437202
# max temp:  0.123977424792
# max abs(c):  0.123977424792
# c_const:  [ 0.12397742]
# error:  [ 0.]
# rank:  235
# G_temp.shape:  (235, 235)
# error 2  0.000465838336269
# max temp:  0.121480703871
# max abs(c):  0.121480703871
# c_const:  [ 0.1214807]
# error:  [ 0.]
# rank:  236
# G_temp.shape:  (236, 236)
# error 2  0.000303397485419
# max temp:  0.119187149036
# max abs(c):  0.119187149036
# c_const:  [ 0.11918715]
# error:  [ 0.]
# rank:  237
# G_temp.shape:  (237, 237)
# error 2  0.000787676061168
# max temp:  0.114397053972
# max abs(c):  0.114397053972
# c_const:  [ 0.11439705]
# error:  [ 0.]
# rank:  238
# G_temp.shape:  (238, 238)
# error 2  0.000226046180331
# max temp:  0.112183915305
# max abs(c):  0.112183915305
# c_const:  [ 0.11218392]
# error:  [ 0.]
# rank:  239
# G_temp.shape:  (239, 239)
# error 2  0.000150031034371
# max temp:  0.110892879389
# max abs(c):  0.110892879389
# c_const:  [ 0.11089288]
# error:  [ 0.]
# rank:  240
# G_temp.shape:  (240, 240)
# error 2  0.000236722960077
# max temp:  0.108978050421
# max abs(c):  0.108978050421
# c_const:  [ 0.10897805]
# error:  [ 0.]
# rank:  241
# G_temp.shape:  (241, 241)
# error 2  7.18016749206e-05
# max temp:  0.107655484507
# max abs(c):  0.107655484507
# c_const:  [ 0.10765548]
# error:  [ 0.]
# rank:  242
# G_temp.shape:  (242, 242)
# error 2  0.000172015049196
# max temp:  0.106424372109
# max abs(c):  0.106424372109
# c_const:  [ 0.10642437]
# error:  [ 0.]
# rank:  243
# G_temp.shape:  (243, 243)
# error 2  1.72015049196e-05
# max temp:  0.105899035869
# max abs(c):  0.105899035869
# c_const:  [ 0.10589904]
# error:  [ 0.]
# rank:  244
# G_temp.shape:  (244, 244)
# error 2  6.40508584457e-05
# max temp:  0.104592470928
# max abs(c):  0.104592470928
# c_const:  [ 0.10459247]
# error:  [ 0.]
# rank:  245
# G_temp.shape:  (245, 245)
# error 2  0.000896312098672
# max temp:  0.0999439488909
# max abs(c):  0.0999439488909
# c_const:  [ 0.09994395]
# error:  [ 0.]
# rank:  246
# G_temp.shape:  (246, 246)
# error 2  0.000562980590805
# max temp:  0.0972640478232
# max abs(c):  0.0972640478233
# c_const:  [ 0.09726405]
# error:  [ 0.]
# rank:  247
# G_temp.shape:  (247, 247)
# error 2  0.000165561251829
# max temp:  0.0958308690936
# max abs(c):  0.0958308690937
# c_const:  [ 0.09583087]
# error:  [ 0.]
# rank:  248
# G_temp.shape:  (248, 248)
# error 2  0.000424854552889
# max temp:  0.0934745109492
# max abs(c):  0.0934745109493
# c_const:  [ 0.09347451]
# error:  [ 0.]
# rank:  249
# G_temp.shape:  (249, 249)
# error 2  0.000650085676511
# max temp:  0.090517510972
# max abs(c):  0.090517510972
# c_const:  [ 0.09051751]
# error:  [ 0.]
# rank:  250
# G_temp.shape:  (250, 250)
# error 2  0.00120677088019
# max temp:  0.0846710831772
# max abs(c):  0.0846710831772
# c_const:  [ 0.08467108]
# error:  [ 0.]
# rank:  251
# G_temp.shape:  (251, 251)
# error 2  0.000120677088019
# max temp:  0.0840335928868
# max abs(c):  0.0840335928869
# c_const:  [ 0.08403359]
# error:  [ 0.]
# rank:  252
# G_temp.shape:  (252, 252)
# error 2  0.000232195161421
# max temp:  0.0825389613519
# max abs(c):  0.0825389613519
# c_const:  [ 0.08253896]
# error:  [ 0.]
# rank:  253
# G_temp.shape:  (253, 253)
# error 2  2.7771565738e-05
# max temp:  0.0821633361102
# max abs(c):  0.0821633361103
# c_const:  [ 0.08216334]
# error:  [ 0.]
# rank:  254
# G_temp.shape:  (254, 254)
# error 2  2.7771565738e-06
# max temp:  0.0821207648913
# max abs(c):  0.0821207648914
# c_const:  [ 0.08212076]
# error:  [ 0.]
# rank:  255
# G_temp.shape:  (255, 255)
# error 2  0.000158955581707
# max temp:  0.0811261016066
# max abs(c):  0.0811261016067
# c_const:  [ 0.0811261]
# error:  [ 0.]
# rank:  256
# G_temp.shape:  (256, 256)
# error 2  0.000116782071961
# max temp:  0.0807082407937
# max abs(c):  0.0807082407937
# c_const:  [ 0.08070824]
# error:  [ 0.]
# rank:  257
# G_temp.shape:  (257, 257)
# error 2  0.000352493349756
# max temp:  0.078918769611
# max abs(c):  0.0789187696111
# c_const:  [ 0.07891877]
# error:  [ 0.]
# rank:  258
# G_temp.shape:  (258, 258)
# error 2  8.68369510893e-05
# max temp:  0.0778487697906
# max abs(c):  0.0778487697906
# c_const:  [ 0.07784877]
# error:  [ 0.]
# rank:  259
# G_temp.shape:  (259, 259)
# error 2  0.000460428962394
# max temp:  0.0749595977122
# max abs(c):  0.0749595977122
# c_const:  [ 0.0749596]
# error:  [ 0.]
# rank:  260
# G_temp.shape:  (260, 260)
# error 2  0.000132650545104
# max temp:  0.0740548706076
# max abs(c):  0.0740548706077
# c_const:  [ 0.07405487]
# error:  [ 0.]
# rank:  261
# G_temp.shape:  (261, 261)
# error 2  0.00017392425455
# max temp:  0.0729171725762
# max abs(c):  0.0729171725763
# c_const:  [ 0.07291717]
# error:  [ 0.]
# rank:  262
# G_temp.shape:  (262, 262)
# error 2  0.000107247379259
# max temp:  0.072266477189
# max abs(c):  0.0722664771891
# c_const:  [ 0.07226648]
# error:  [ 0.]
# rank:  263
# G_temp.shape:  (263, 263)
# error 2  0.000706992731206
# max temp:  0.0694775431031
# max abs(c):  0.0694775431032
# c_const:  [ 0.06947754]
# error:  [ 0.]
# rank:  264
# G_temp.shape:  (264, 264)
# error 2  0.00122922617654
# max temp:  0.0660077521314
# max abs(c):  0.0660077521314
# c_const:  [ 0.06600775]
# error:  [ 0.]
# rank:  265
# G_temp.shape:  (265, 265)
# error 2  0.00020702029588
# max temp:  0.0642011325586
# max abs(c):  0.0642011325587
# c_const:  [ 0.06420113]
# error:  [ 0.]
# rank:  266
# G_temp.shape:  (266, 266)
# error 2  0.000252214242454
# max temp:  0.0623118541735
# max abs(c):  0.0623118541735
# c_const:  [ 0.06231185]
# error:  [ 0.]
# rank:  267
# G_temp.shape:  (267, 267)
# error 2  0.000376860555378
# max temp:  0.0604422841853
# max abs(c):  0.0604422841853
# c_const:  [ 0.06044228]
# error:  [ 0.]
# rank:  268
# G_temp.shape:  (268, 268)
# error 2  0.00012451633058
# max temp:  0.0591193826721
# max abs(c):  0.0591193826721
# c_const:  [ 0.05911938]
# error:  [ 0.]
# rank:  269
# G_temp.shape:  (269, 269)
# error 2  1.2451633058e-05
# max temp:  0.0590140860064
# max abs(c):  0.0590140860065
# c_const:  [ 0.05901409]
# error:  [ 0.]
# rank:  270
# G_temp.shape:  (270, 270)
# error 2  0.000997926076155
# max temp:  0.054473397896
# max abs(c):  0.054473397896
# c_const:  [ 0.0544734]
# error:  [ 0.]
# rank:  271
# G_temp.shape:  (271, 271)
# error 2  0.000134630613844
# max temp:  0.0536028489249
# max abs(c):  0.053602848925
# c_const:  [ 0.05360285]
# error:  [ 0.]
# rank:  272
# G_temp.shape:  (272, 272)
# error 2  0.000164222320486
# max temp:  0.0524715856112
# max abs(c):  0.0524715856112
# c_const:  [ 0.05247159]
# error:  [ 0.]
# rank:  273
# G_temp.shape:  (273, 273)
# error 2  0.000679097369473
# max temp:  0.0475627650941
# max abs(c):  0.0475627650942
# c_const:  [ 0.04756277]
# error:  [ 0.]
# rank:  274
# G_temp.shape:  (274, 274)
# error 2  0.000529518242823
# max temp:  0.0438237376283
# max abs(c):  0.0438237376284
# c_const:  [ 0.04382374]
# error:  [ 0.]
# rank:  275
# G_temp.shape:  (275, 275)
# error 2  0.000400085317657
# max temp:  0.0397443305784
# max abs(c):  0.0397443305785
# c_const:  [ 0.03974433]
# error:  [ 0.]
# rank:  276
# G_temp.shape:  (276, 276)
# error 2  8.12231030826e-05
# max temp:  0.03741282726
# max abs(c):  0.0374128272601
# c_const:  [ 0.03741283]
# error:  [ 0.]
# rank:  277
# G_temp.shape:  (277, 277)
# error 2  0.000653395040951
# max temp:  0.0331357575019
# max abs(c):  0.0331357575019
# c_const:  [ 0.03313576]
# error:  [ 0.]
# rank:  278
# G_temp.shape:  (278, 278)
# error 2  8.19181998143e-05
# max temp:  0.0325023959173
# max abs(c):  0.0325023959173
# c_const:  [ 0.0325024]
# error:  [ 0.]
# rank:  279
# G_temp.shape:  (279, 279)
# error 2  9.79160976744e-05
# max temp:  0.0320107525487
# max abs(c):  0.0320107525488
# c_const:  [ 0.03201075]
# error:  [ 0.]
# rank:  280
# G_temp.shape:  (280, 280)
# error 2  2.43284899468e-05
# max temp:  0.031799098825
# max abs(c):  0.0317990988251
# c_const:  [ 0.0317991]
# error:  [ 0.]
# rank:  281
# G_temp.shape:  (281, 281)
# error 2  0.000373781222856
# max temp:  0.0293449935041
# max abs(c):  0.0293449935041
# c_const:  [ 0.02934499]
# error:  [ 0.]
# rank:  282
# G_temp.shape:  (282, 282)
# error 2  0.00115213364888
# max temp:  0.0228402080341
# max abs(c):  0.0228402080341
# c_const:  [ 0.02284021]
# error:  [ 0.]
# rank:  283
# G_temp.shape:  (283, 283)
# error 2  0.000115213364888
# max temp:  0.0220053552413
# max abs(c):  0.0220053552413
# c_const:  [ 0.02200536]
# error:  [ 0.]
# rank:  284
# G_temp.shape:  (284, 284)
# error 2  0.000202107404121
# max temp:  0.0209287953082
# max abs(c):  0.0209287953082
# c_const:  [ 0.0209288]
# error:  [ 0.]
# rank:  285
# G_temp.shape:  (285, 285)
# error 2  0.000427852772585
# max temp:  0.0186662363161
# max abs(c):  0.0186662363162
# c_const:  [ 0.01866624]
# error:  [ 0.]
# rank:  286
# G_temp.shape:  (286, 286)
# error 2  0.000206303325285
# max temp:  0.0166569325845
# max abs(c):  0.0166569325846
# c_const:  [ 0.01665693]
# error:  [ 0.]
# rank:  287
# G_temp.shape:  (287, 287)
# error 2  3.58548899255e-05
# max temp:  0.0164651301196
# max abs(c):  0.0164651301196
# c_const:  [ 0.01646513]
# error:  [ 0.]
# rank:  288
# G_temp.shape:  (288, 288)
# error 2  2.38123722361e-05
# max temp:  0.0162806041566
# max abs(c):  0.0162806041566
# c_const:  [ 0.0162806]
# error:  [ 0.]
# rank:  289
# G_temp.shape:  (289, 289)
# error 2  6.06241167178e-06
# max temp:  0.016200388872
# max abs(c):  0.0162003888721
# c_const:  [ 0.01620039]
# error:  [ 0.]
# rank:  290
# G_temp.shape:  (290, 290)
# error 2  0.00023280285054
# max temp:  0.0146277074642
# max abs(c):  0.0146277074642
# c_const:  [ 0.01462771]
# error:  [ 0.]
# rank:  291
# G_temp.shape:  (291, 291)
# error 2  0.000250282105323
# max temp:  0.011271316806
# max abs(c):  0.0112713168061
# c_const:  [ 0.01127132]
# error:  [ 0.]
# rank:  292
# G_temp.shape:  (292, 292)
# error 2  0.000146040337162
# max temp:  0.00929779407094
# max abs(c):  0.00929779407099
# c_const:  [ 0.00929779]
# error:  [ 0.]
# rank:  293
# G_temp.shape:  (293, 293)
# error 2  6.53177381964e-05
# max temp:  0.00852210120318
# max abs(c):  0.00852210120324
# c_const:  [ 0.0085221]
# error:  [ 0.]
# rank:  294
# G_temp.shape:  (294, 294)
# error 2  3.04296595499e-05
# max temp:  0.00839780888971
# max abs(c):  0.00839780888976
# c_const:  [ 0.00839781]
# error:  [ 0.]
# rank:  295
# G_temp.shape:  (295, 295)
# error 2  0.000125949386414
# max temp:  0.00603418298983
# max abs(c):  0.00603418298988
# c_const:  [ 0.00603418]
# error:  [ 0.]
# rank:  296
# G_temp.shape:  (296, 296)
# error 2  1.25949386414e-05
# max temp:  0.00590593448104
# max abs(c):  0.00590593448109
# c_const:  [ 0.00590593]
# error:  [ 0.]
# rank:  297
# G_temp.shape:  (297, 297)
# error 2  0.000316282063856
# max temp:  0.00497675046066
# max abs(c):  0.00497675046071
# c_const:  [ 0.00497675]
# error:  [ 0.]
# rank:  298
# G_temp.shape:  (298, 298)
# error 2  3.69750300929e-05
# max temp:  0.00479518427385
# max abs(c):  0.0047951842739
# c_const:  [ 0.00479518]
# error:  [ 0.]
# rank:  299
# G_temp.shape:  (299, 299)
# error 2  0.00053803668182
# max temp:  0.000868390850411
# max abs(c):  0.000868390850463
# c_const:  [ 0.00086839]
# error:  [ 0.]
# rank:  300
# G_temp.shape:  (300, 300)

# %%
gamma
# Out:
# array([ 0.23110119])

# %%
c_const*h
# Out:
# array([ 0.01699045])

# %%
c_const*h
# Out:
# array([ 0.10530783])

# %%
sum(a)
# Out:
# -1.9916344594467172

# %%
print(sum(A[:,9]))
# Out:
#   (0, 0)	17.6564492694

# %%
A[0,0]
# Out:
# 0.033922676577637915

# %%
b[0]
# Out:
# -1.0

# %%
np.linalg.eig(rhs_Omega)[0]
# Out:
# array([ 0.49590424,  0.04291059])

# %%
A_B_t_A_B - np.dot(H.T,H)
# Out:
# array([[  4.95904200e-01,  -1.30800199e-04],
#        [ -1.30800199e-04,   4.29106287e-02]])

# %%
A_B_t_A_B
# Out:
# array([[ 1.,  0.],
#        [ 0.,  1.]])

# %%
np.dot(H.T,H)
# Out:
# array([[  5.04095800e-01,   1.30800199e-04],
#        [  1.30800199e-04,   9.57089371e-01]])

# %%
L_t = L2[0:274,0:274]

# %%
G_local = A_local[:,A_hallow].T.dot(A_local[:,A_hallow]).toarray()
L2 = np.linalg.cholesky(G_local)

# %%
adf2 = sp_linalg.solve_triangular(L_t,A_hallow_t_old_A_B[:,1],lower=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-1b628c9718a6> in <module>()
# ----> 1 adf2 = sp_linalg.solve_triangular(L_t,A_hallow_t_old_A_B[:,1],lower=True)
#
# /usr/local/lib/python3.6/site-packages/scipy/linalg/basic.py in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, debug, check_finite)
#     286         raise ValueError('expected square matrix')
#     287     if a1.shape[0] != b1.shape[0]:
# --> 288         raise ValueError('incompatible dimensions')
#     289     overwrite_b = overwrite_b or _datacopied(b1, b)
#     290     if debug:
#
# ValueError: incompatible dimensions

# %%
np.dot(H.T,H)
# Out:
# array([[  5.04095800e-01,   1.30800199e-04],
#        [  1.30800199e-04,   9.57089371e-01]])

# %%
np.dot(adf,adf)
# Out:
# 1.0000000000000002

# %%
np.linalg.matrix_rank(A_hallow_t_old_A_B)
# Out:
# 2

# %%
np.amax(A)
# Out:
# <7366x300 sparse matrix of type '<class 'numpy.float64'>'
# 	with 86288 stored elements in LInked List format>
